# %%
from get_results import getResults
from datetime import date, timedelta
import pandas as pd

# %%
# df = pd.read_csv('old_record.csv')
df = pd.read_csv('record.csv')

# %%
df
# Out:
#          Date            Home Team              Away Team  X Home Goals  \
# 0  2024-03-05    New Jersey Devils       Florida Panthers          2.68
# 1  2024-03-05  Pittsburgh Penguins  Columbus Blue Jackets          3.29
# 2  2024-03-05        Boston Bruins        Edmonton Oilers          3.42
# 3  2024-03-05   New York Islanders         St Louis Blues          3.34
# 4  2024-03-05  Nashville Predators     Montreal Canadiens          4.13
# 5  2024-03-05        Winnipeg Jets         Seattle Kraken          3.35
# 6  2024-03-05      Arizona Coyotes     Chicago Blackhawks          3.77
# 7  2024-03-05    Los Angeles Kings      Vancouver Canucks          3.79
# 8  2024-03-05      San Jose Sharks           Dallas Stars          3.32
#
#    X Away Goals  X Home Spread               X Winner  Home Goals  Away Goals  \
# 0          3.90          -1.22       Florida Panthers         NaN         NaN
# 1          4.02          -0.73  Columbus Blue Jackets         NaN         NaN
# 2          4.02          -0.60        Edmonton Oilers         NaN         NaN
# 3          3.51          -0.17         St Louis Blues         NaN         NaN
# 4          3.04           1.09    Nashville Predators         NaN         NaN
# 5          3.00           0.35          Winnipeg Jets         NaN         NaN
# 6          3.51           0.26        Arizona Coyotes         NaN         NaN
# 7          3.20           0.59      Los Angeles Kings         NaN         NaN
# 8          3.73          -0.41           Dallas Stars         NaN         NaN
#
#    Winner  Unnamed: 10
# 0     NaN          NaN
# 1     NaN          NaN
# 2     NaN          NaN
# 3     NaN          NaN
# 4     NaN          NaN
# 5     NaN          NaN
# 6     NaN          NaN
# 7     NaN          NaN
# 8     NaN          NaN

# %%
ystd = str(date.today() - timedelta(days=1))
ystd = ''.join(ystd.split('-'))
scoresDF = getResults(ystd)

# %%
scoresDF
# Out:
#          Date     Home Team       Away Team Home Goals Away Goals  \
# 0  2024-03-04   Maple Leafs          Bruins          1          4
# 1  2024-03-04       Rangers        Panthers          2          4
# 2  2024-03-04        Flyers           Blues          1          2
# 3  2024-03-04  Blue Jackets  Golden Knights          6          3
# 4  2024-03-04     Avalanche      Blackhawks          5          0
# 5  2024-03-04        Flames          Kraken          2          4
#
#          Winner
# 0        Bruins
# 1      Panthers
# 2         Blues
# 3  Blue Jackets
# 4     Avalanche
# 5        Kraken

# %%
# Initialize an empty list to store the matched rows
matched_rows = []

# Iterate over the rows of results
for index, row in scoresDF.iterrows():
    # to filter by
    date_value = str(row['Date'])
    partial_string = row['Home Team']
    # to include in result
    home_goals = row['Home Goals']
    away_goals = row['Away Goals']
    winner = row['Winner']

    matched_df_rows = df[(df['Date'] == date_value) & (df['Home Team'].str.contains(partial_string))]
    # If there are matches, add them to the list
    if not matched_df_rows.empty:
        for _, matched_row in matched_df_rows.iterrows():
            # Add the matched row from df1 and the corresponding row from df2 to the list
            matched_rows.append(matched_row.tolist() + [home_goals, away_goals, winner])

print(matched_rows)
# Out:
# []

# %%
# Create a DataFrame from the matched rows
merged_df = pd.DataFrame(matched_rows, columns=list(df.columns) + ['Home Goals', 'Away Goals', 'Winner'])

# Print the merged DataFrame
print(merged_df)
# Out:
# Empty DataFrame
# Columns: [Date, Home Team, Away Team, X Home Goals, X Away Goals, X Home Spread, X Winner, Home Goals, Away Goals, Winner, Unnamed: 10, Home Goals, Away Goals, Winner]
# Index: []

# %%
# Write today's predictions to csv
f = open("record.csv", 'a')

for col in merged_df.values:
    for row in col:
        f.write(str(row) + ",")
    f.write("\n")

f.close()
